# %%
api='AIzaSyA92Z9ON5SZBry7PMcUkV_WLxjm8_SBnfg'

# %%
c_id='UC2J_VKrAzOEJuQvFFtj3KUw'

# %%
pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
from googleapiclient.discovery import build
from pprint import pprint

# %%
youtube = build("youtube", "v3", developerKey=api)

# %%
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id='UC2J_VKrAzOEJuQvFFtj3KUw'
        
    )
response = request.execute()
print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'BvkOQGFS3Tl1tSfMVj3eEwzHE3c', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'ZZmEfql7WMpxtcS1bm-eqjhpbrY', 'id': 'UC2J_VKrAzOEJuQvFFtj3KUw', 'snippet': {'title': 'Chennai Super Kings', 'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove', 'customUrl': '@chennaiipl', 'publishedAt': '2009-04-17T13:00:30Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localize
# ...

# %%
pprint(response)
# Out:
# {'etag': 'BvkOQGFS3Tl1tSfMVj3eEwzHE3c',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UU2J_VKrAzOEJuQvFFtj3KUw'}},
#             'etag': 'ZZmEfql7WMpxtcS1bm-eqjhpbrY',
#             'id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'IN',
#                         'customUrl': '@chennaiipl',
#                         'description': 'The Official YouTube Channel of the '
#                                        'Chennai Super Kings. #WhistlePodu '
#                                        '#Yellove',
#                         'localized': {'description': 'The Official YouTube '
#                                                      'Channel of the Chennai '
#                                                      'Super Kings. '
#                                                      '#WhistlePodu #Yellove',
# ...

# %%
dict(title = response['items'][0]['snippet']['title'],
description = response['items'][0]['snippet']['description'],
subscribercount = response['items'][0]['statistics']['subscriberCount'],
videocount = response['items'][0]['statistics']['videoCount'],
playlist_id = response['items'][0]['id'],
viewcount = response['items'][0]['statistics']['viewCount'])
# Out:
# {'title': 'Chennai Super Kings',
#  'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove',
#  'subscribercount': '3150000',
#  'videocount': '1107',
#  'playlist_id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#  'viewcount': '626789224'}

# %%
def channel_details(c_id):
  request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=c_id

    )
  response = request.execute()
  z = dict(title = response['items'][0]['snippet']['title'],
         description = response['items'][0]['snippet']['description'],
         subscribercount = response['items'][0]['statistics']['subscriberCount'],
         videocount = response['items'][0]['statistics']['videoCount'],
         playlist_id = response['items'][0]['id'],
         viewcount = response['items'][0]['statistics']['viewCount'])
  return z

# %%
channel_details('UC2J_VKrAzOEJuQvFFtj3KUw')
# Out:
# {'title': 'Chennai Super Kings',
#  'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove',
#  'subscribercount': '3150000',
#  'videocount': '1107',
#  'playlist_id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#  'viewcount': '626789224'}

# %%
#for video_id
def get_channel_videos(c_id):
  video_ids=[]
  res = youtube.channels().list(id=c_id,
                                part='contentDetails').execute()
  playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
  next_page_token = None

  while True:
    res = youtube.playlistItems().list(playlistId=playlist_id,
                                        part='snippet',
                                        maxResults=50,
                                        pageToken=next_page_token).execute()
    for i in range(len(res['items'])):
      video_ids.append(res['items'][i]['snippet']['resourceId']['videoId'])
    next_page_token = res.get('nextPageToken')

    if next_page_token is None:
      break
    return video_ids

# %%
get_channel_videos('UC2J_VKrAzOEJuQvFFtj3KUw')
# Out:
# ['5ksUpqdLHfc',
#  'WB4Ml8yjC2k',
#  'rXT9J3j0mPY',
#  '98W-G7hEPvY',
#  '2jU1xTBLBGs',
#  'lqjFpog8ZcA',
#  'KVhfaeC1LN4',
#  'w1tx7gH4-2w',
#  'fx8PhBgkiv8',
#  'baLQHOTWm3o',
#  'Erkjh_RM5y0',
#  'm_wYkpVaWCs',
#  'HYzJBwP40t0',
#  '6zv8mzeqZn0',
#  'IjsR8UBoUkE',
#  'f1gnaV4sWYo',
#  '85adJ60bQqk',
#  'zdZmopaH8vA',
#  'r88fWNdYmPc',
#  'o29L2ysDYeY',
#  'DntAi1keBkg',
#  'sWldDPznq60',
#  'R6v4PyiDOMI',
#  '51BFx3J2Ru4',
#  'xlripGf89Aw',
#  'Q4wsTEV8_XM',
#  'XZ0n5vOCj6U',
#  'W4P5AyK7Ues',
#  'RtD4q4LnLUw',
#  'WxbZtVJLID4',
#  '9OPmzW31nzk',
#  'MbzuFYeq4aU',
#  'fGHl5k_PyNE',
#  'g87iuCiFM0E',
#  '1QyC0VyxjUA',
#  'JNs4p0pk8Ms',
#  'dsMLIZKIEd8',
#  'QJNsvEta0UI',
#  'iVWyETew2KM',
#  '0b6rhoi1pAQ',
#  'RF3gM9MUPwk',
#  'FCJyVOtupZg',
#  '-zEynAwpLVI',
#  '_xYIJwAgJ_k',
#  'as-5cUQfhBk',
#  'ss4vpidhoHU',
#  'mXm-VjKPd1g',
#  'k-QBfI95DT8',
#  'z4fIO1-qF5Q',
#  'AD75Jds6EfI']

# %%
#to get video details
def get_video_details(video_ids):
  video_starts=[]

  for i in range(0,len(video_ids),50):
    response = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=video_ids).execute()
  for video in response['items']:
    video_details = dict(Channel_name = video['snippet']['channelTitle'],
                         Channel_id = video['snippet']['channelId'],
                         Video_id = video['id'],
                         Title = video['snippet']['title'],
                         Tags = video['snippet'].get('tags'),
                         Thumbnail = video['snippet']['thumbnails']['default']['url'],
                         Description = video['snippet']['description'],
                         Published_date = video['snippet']['publishedAt'],
                         Duration = video['contentDetails']['duration'],
                         views = video['statistics']['viewCount'],
                         Likes = video['statistics'].get('likeCount'),
                         Comments = video['statistics'].get('commentContent'),
                         Favorite_count = video['statistics']['favoriteCount'],
                         )
    video_starts.append(video_details)
    return video_starts

# %%
get_video_details('vKaEjIPEGxc')
# Out:
# [{'Channel_name': 'Chennai Super Kings',
#   'Channel_id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#   'Video_id': 'vKaEjIPEGxc',
#   'Title': "Moeen Ali reflects on the Summer of 23' so far | Lions upclose",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/vKaEjIPEGxc/default.jpg',
#   'Description': 'Upclose and personal with Ali Bhai on the season so far, the fans support and lots more..!\n\nWatch the full episode 📹🔽\n\n#WhistlePodu #Yellove 🦁💛',
#   'Published_date': '2023-05-19T15:36:47Z',
#   'Duration': 'PT7M18S',
#   'views': '48477',
#   'Likes': '2905',
#   'Comments': None,
#   'Favorite_count': '0'}]

# %%
def get_comments_details(video_ids):
  comment_data = []
  for i in video_ids:
    try:
      response = youtube.commentThreads().list(part="snippet,replies",
                                               videoId=video_ids,
                                               maxResults=100).execute()
      for cmt in response['items']:
        data = dict(Comment_id = cmt['id'],
                    Video_id = cmt['snippet']['videoId'],
                    Comment_text = cmt['snippet']['topLevelComment']['snippet']['textDisplay'],
                    Comment_author = cmt['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                    Comment_posted_date = cmt['snippet']['topLevelComment']['snippet']['publishedAt'],
                    like_count = cmt['snippet']['topLevelComment']['snippet']['likeCount'],
                    Reply_count = cmt['snippet']['totalReplyCount']
                    )
        comment_data.append(data)

    except:
      pass
  return comment_data

# %%
get_comments_details('vKaEjIPEGxc')
# Out:
# [{'Comment_id': 'UgzG5cbbDohabKcchY54AaABAg',
#   'Video_id': 'vKaEjIPEGxc',
#   'Comment_text': 'Moeen is 🐐 Goat',
#   'Comment_author': 'Bhartiya Cricket Fan (Formerly Indian Cricket Fan)',
#   'Comment_posted_date': '2023-06-29T15:05:25Z',
#   'like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzB5OYPeHoVaLNvtq14AaABAg',
#   'Video_id': 'vKaEjIPEGxc',
#   'Comment_text': 'Ali bai',
#   'Comment_author': 'Agash Babu',
#   'Comment_posted_date': '2023-06-18T08:54:33Z',
#   'like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwpCxXjTpHT90CF1b54AaABAg',
#   'Video_id': 'vKaEjIPEGxc',
#   'Comment_text': 'Chennai is not massive, dhoni is massive 💪🏻',
#   'Comment_author': 'Magic Skate',
#   'Comment_posted_date': '2023-05-25T18:21:49Z',
#   'like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy0eFfe6lQRyXr6zwp4AaABAg',
#   'Video_id': 'vKaEjIPEGxc',
#   'Comment_text': 'Terrorist 💥💣',
#   'Comment_author': 'Praveen Kumar',
# ...

# %%
def main_function():
  channel_id = input("enter channel ID")
  channelDetails = channel_details(channel_id)
  v_ids = get_channel_videos(channel_id)
  video_deatils = get_video_details(v_ids[0])
  comment_details = get_comments_details(v_ids[0])
  print(comment_details)
  print("===============")

  data={"ChannelDetails":channeldetails,
        "video_details":video_details,
        "video IDs": v_ids,
        "Comments": comment_deatils}
  return data

# %%
main_function()

# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
db = client["mydatabase"]

# %%
collection = db["mycollection"]

# %%
result = collection.insert_many('channel_details')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Aparnaa\project.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Aparnaa/project.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> result = collection.insert_many('channel_details')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymongo\collection.py:756, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     754 write_concern = self._write_concern_for(session)
#     755 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
# --> 756 blk.ops = list(gen())
# ...
